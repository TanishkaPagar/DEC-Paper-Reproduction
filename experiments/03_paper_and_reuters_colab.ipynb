# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !python -m src.train --schedule paper
# Out:
# /usr/bin/python3: Error while finding module specification for 'src.train' (ModuleNotFoundError: No module named 'src')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p /content/drive/MyDrive/dec_checkpoints
# %cd /content
# !rm -rf DEC-Paper-Reproduction
# !git clone https://github.com/TanishkaPagar/DEC-Paper-Reproduction.git
# %cd DEC-Paper-Reproduction
# Out:
# /content
# Cloning into 'DEC-Paper-Reproduction'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 66 (delta 28), reused 52 (delta 15), pack-reused 0 (from 0)
# Receiving objects: 100% (66/66), 879.57 KiB | 12.05 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/DEC-Paper-Reproduction

# %%
# !python -m src.train --schedule paper --ckpt_dir /content/drive/MyDrive/dec_checkpoints
# Out:
# Using device: cuda
# Training schedule: paper
# Checkpoint directory: /content/drive/MyDrive/dec_checkpoints
# 100% 9.91M/9.91M [00:00<00:00, 60.0MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 1.55MB/s]
# 100% 1.65M/1.65M [00:00<00:00, 14.3MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 13.7MB/s]
# --- [paper] Pretraining layer pair 1/4 (50000 iterations) ---
#   iter 5000/50000  lr=1e-01  avg_loss=0.0575
#   iter 10000/50000  lr=1e-01  avg_loss=0.0406
#   iter 15000/50000  lr=1e-01  avg_loss=0.0391
#   iter 20000/50000  lr=1e-01  avg_loss=0.0382
#   iter 25000/50000  lr=1e-02  avg_loss=0.0376
#   iter 30000/50000  lr=1e-02  avg_loss=0.0376
#   iter 35000/50000  lr=1e-02  avg_loss=0.0375
#   iter 40000/50000  lr=1e-02  avg_loss=0.0375
#   iter 45000/50000  lr=1e-03  avg_loss=0.0374
#   iter 50000/50000  lr=1e-03  avg_loss=0.0374
#   [checkpoint saved: /content/drive/MyDrive/dec_checkpoints/checkpoint_after_layer1.pth]
# --- [paper] Pretraining layer pair 2/4 (50000 iterations) ---
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !rm -rf DEC-Paper-Reproduction
# !git clone https://github.com/TanishkaPagar/DEC-Paper-Reproduction.git
# %cd DEC-Paper-Reproduction
# Out:
# /content
# Cloning into 'DEC-Paper-Reproduction'...
# remote: Enumerating objects: 74, done.
# remote: Counting objects: 100% (74/74), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 74 (delta 34), reused 56 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (74/74), 882.22 KiB | 910.00 KiB/s, done.
# Resolving deltas: 100% (34/34), done.
# /content/DEC-Paper-Reproduction

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !python -m src.train_reuters --ckpt_dir /content/drive/MyDrive/dec_checkpoints
# Out:
# Using device: cuda
# Fetching RCV1 (first call downloads ~700MB)...
# Documents with exactly one root category: 685071
# REUTERS-10k ready: x=(10000, 2000), y=(10000,), classes=[4383  825 2361 2431]
# --- Pretraining layer pair 1/4 ---
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/DEC-Paper-Reproduction/src/train_reuters.py", line 93, in <module>
#     train_dec_reuters(ckpt_dir=args.ckpt_dir)
#   File "/content/DEC-Paper-Reproduction/src/train_reuters.py", line 37, in train_dec_reuters
#     pretrain_layerwise(sae, loader, device)
#   File "/content/DEC-Paper-Reproduction/src/autoencoder.py", line 92, in pretrain_layerwise
#     hidden = enc_k(h_noisy)
#              ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1779, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
# ...

# %%
# !git pull
# !python -m src.train_reuters --ckpt_dir /content/drive/MyDrive/dec_checkpoints
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# /usr/bin/python3: Error while finding module specification for 'src.train_reuters' (ModuleNotFoundError: No module named 'src')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content
# !rm -rf DEC-Paper-Reproduction
# !git clone https://github.com/TanishkaPagar/DEC-Paper-Reproduction.git
# %cd DEC-Paper-Reproduction
# Out:
# /content
# Cloning into 'DEC-Paper-Reproduction'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (54/54), done.
# remote: Total 78 (delta 37), reused 60 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 882.51 KiB | 22.63 MiB/s, done.
# Resolving deltas: 100% (37/37), done.
# /content/DEC-Paper-Reproduction

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !python -m src.train_reuters --ckpt_dir /content/drive/MyDrive/dec_checkpoints
# Out:
# Using device: cuda
# Fetching RCV1 (first call downloads ~700MB)...
# Documents with exactly one root category: 685071
# REUTERS-10k ready: x=(10000, 2000), y=(10000,), classes=[4383  825 2361 2431]
# --- Pretraining layer pair 1/4 ---
#   epoch 1/25  loss=0.9252
#   epoch 2/25  loss=0.7633
#   epoch 3/25  loss=0.6490
#   epoch 4/25  loss=0.5881
#   epoch 5/25  loss=0.5552
#   epoch 6/25  loss=0.5372
#   epoch 7/25  loss=0.5239
#   epoch 8/25  loss=0.5148
#   epoch 9/25  loss=0.5080
#   epoch 10/25  loss=0.5037
#   epoch 11/25  loss=0.4979
#   epoch 12/25  loss=0.4943
#   epoch 13/25  loss=0.4908
#   epoch 14/25  loss=0.4890
#   epoch 15/25  loss=0.4871
#   epoch 16/25  loss=0.4845
#   epoch 17/25  loss=0.4832
#   epoch 18/25  loss=0.4807
#   epoch 19/25  loss=0.4792
#   epoch 20/25  loss=0.4783
#   epoch 21/25  loss=0.4779
#   epoch 22/25  loss=0.4772
#   epoch 23/25  loss=0.4758
#   epoch 24/25  loss=0.4729
#   epoch 25/25  loss=0.4736
# --- Pretraining layer pair 2/4 ---
# ...
