# %%
# %cd /content
# !rm -rf DEC-Paper-Reproduction
# !git clone https://github.com/TanishkaPagar/DEC-Paper-Reproduction.git
# %cd DEC-Paper-Reproduction
# Out:
# /content
# Cloning into 'DEC-Paper-Reproduction'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 14 (delta 3), reused 14 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 5.88 KiB | 5.88 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/DEC-Paper-Reproduction

# %%
# !python -m src.train
# Out:
# Using device: cuda
# 100% 9.91M/9.91M [00:00<00:00, 19.9MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 473kB/s]
# 100% 1.65M/1.65M [00:00<00:00, 4.45MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 25.5MB/s]
# --- Pretraining layer pair 1/4 ---
#   epoch 1/25  loss=0.0834
#   epoch 2/25  loss=0.0436
#   epoch 3/25  loss=0.0410
#   epoch 4/25  loss=0.0399
#   epoch 5/25  loss=0.0393
#   epoch 6/25  loss=0.0387
#   epoch 7/25  loss=0.0381
#   epoch 8/25  loss=0.0376
#   epoch 9/25  loss=0.0371
#   epoch 10/25  loss=0.0367
#   epoch 11/25  loss=0.0363
#   epoch 12/25  loss=0.0359
#   epoch 13/25  loss=0.0355
#   epoch 14/25  loss=0.0352
#   epoch 15/25  loss=0.0350
#   epoch 16/25  loss=0.0347
#   epoch 17/25  loss=0.0343
#   epoch 18/25  loss=0.0341
#   epoch 19/25  loss=0.0337
#   epoch 20/25  loss=0.0334
#   epoch 21/25  loss=0.0332
#   epoch 22/25  loss=0.0329
#   epoch 23/25  loss=0.0327
#   epoch 24/25  loss=0.0325
#   epoch 25/25  loss=0.0322
# --- Pretraining layer pair 2/4 ---
# ...

# %%
# !git pull
# !mkdir -p results/figures
# !python -m experiments.visualize_tsne
# Out:
# fatal: not a git repository (or any of the parent directories): .git
# /usr/bin/python3: Error while finding module specification for 'experiments.visualize_tsne' (ModuleNotFoundError: No module named 'experiments')

# %%
# %cd /content
# !rm -rf DEC-Paper-Reproduction
# !git clone https://github.com/TanishkaPagar/DEC-Paper-Reproduction.git
# %cd DEC-Paper-Reproduction
# !mkdir -p results/figures
# Out:
# /content
# Cloning into 'DEC-Paper-Reproduction'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 23 (delta 6), reused 22 (delta 5), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 9.81 KiB | 4.90 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/DEC-Paper-Reproduction

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !python -m experiments.visualize_tsne
# Out:
# Using device: cuda
# 100% 9.91M/9.91M [00:00<00:00, 19.8MB/s]
# 100% 28.9k/28.9k [00:00<00:00, 475kB/s]
# 100% 1.65M/1.65M [00:00<00:00, 4.40MB/s]
# 100% 4.54k/4.54k [00:00<00:00, 20.5MB/s]
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/DEC-Paper-Reproduction/experiments/visualize_tsne.py", line 71, in <module>
#     main()
#   File "/content/DEC-Paper-Reproduction/experiments/visualize_tsne.py", line 43, in main
#     sae.load_state_dict(torch.load("sae_pretrained.pth", map_location=device))
#                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 1530, in load
#     with _open_file_like(f, "rb") as opened_file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/serialization.py", line 795, in _open_file_like
# ...

# %%
# !ls /content
# !ls /content/DEC-Paper-Reproduction
# Out:
# DEC-Paper-Reproduction	results  sample_data
# data  experiments  README.md  requirements.txt	results  src

# %%
# !ls /content/DEC-Paper-Reproduction
# Out:
# data	       experiments  requirements.txt  sae_pretrained.pth
# dec_final.pth  README.md    results	      src

# %%
# !python -m experiments.visualize_tsne
# Out:
# Using device: cuda
# Running t-SNE: Before DEC (autoencoder embedding) ...
# Running t-SNE: After DEC (KL-optimized embedding) ...
# Saved: results/figures/tsne_before_after_dec.png

# %%
# !git pull
# !python -m experiments.ablation_no_backprop
# Out:
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 10 (delta 3), reused 10 (delta 3), pack-reused 0 (from 0)
# Unpacking objects: 100% (10/10), 585.21 KiB | 10.09 MiB/s, done.
# From https://github.com/TanishkaPagar/DEC-Paper-Reproduction
#    70a12d5..ac4dc2a  main       -> origin/main
# Updating 70a12d5..ac4dc2a
# error: The following untracked working tree files would be overwritten by merge:
# 	results/figures/tsne_before_after_dec.png
# Please move or remove them before you merge.
# Aborting
# /usr/bin/python3: No module named experiments.ablation_no_backprop

# %%
# !rm results/figures/tsne_before_after_dec.png
# !git pull
# Out:
# Updating 70a12d5..ac4dc2a
# Fast-forward
#  README.md                                 |   9 ++++
#  experiments/ablation_no_backprop.py       |  83 ++++++++++++++++++++++++++++++
#  results/figures/tsne_before_after_dec.png | Bin 0 -> 604251 bytes
#  3 files changed, 92 insertions(+)
#  create mode 100644 experiments/ablation_no_backprop.py
#  create mode 100644 results/figures/tsne_before_after_dec.png

# %%
# !python -m experiments.ablation_no_backprop
# Out:
# Using device: cuda
# AE + k-means  ACC=0.7693  NMI=0.7378
# iter   0  ACC=0.7693  NMI=0.7378  changed=0.0000%
# iter   1  ACC=0.7703  NMI=0.7389  changed=0.3571%
# iter   2  ACC=0.7708  NMI=0.7393  changed=0.2271%
# iter   3  ACC=0.7708  NMI=0.7387  changed=0.2714%
# iter   4  ACC=0.7703  NMI=0.7374  changed=0.2429%
# iter   5  ACC=0.7701  NMI=0.7366  changed=0.2586%
# iter   6  ACC=0.7696  NMI=0.7356  changed=0.2557%
# iter   7  ACC=0.7690  NMI=0.7345  changed=0.2243%
# iter   8  ACC=0.7683  NMI=0.7332  changed=0.2571%
# iter   9  ACC=0.7674  NMI=0.7316  changed=0.2614%
# iter  10  ACC=0.7666  NMI=0.7301  changed=0.2114%
# iter  11  ACC=0.7657  NMI=0.7288  changed=0.2371%
# iter  12  ACC=0.7648  NMI=0.7272  changed=0.2286%
# iter  13  ACC=0.7641  NMI=0.7259  changed=0.2043%
# iter  14  ACC=0.7635  NMI=0.7250  changed=0.1943%
# iter  15  ACC=0.7629  NMI=0.7240  changed=0.1586%
# iter  16  ACC=0.7622  NMI=0.7229  changed=0.1557%
# iter  17  ACC=0.7616  NMI=0.7220  changed=0.1543%
# ...
